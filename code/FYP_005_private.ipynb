# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/Qiliang/bart-large-cnn-samsum-ChatGPT_v3"
headers = {"Authorization": "Bearer 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"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.json()

output = query({
    "inputs": "The answer to the universe is",
})

# %%
output[0]['generated_text']
# Out:
# 'The answer to the universe is "The God\'s Planets" according to Albert Einstein. The God\'s Theory of the Universe is the answer to all questions about the universe\'s origin and origin.    The god\'s planets are the origin of all things in the universe.'

# %%
output = query({
    "inputs": "interview me as a Machine Learning expert",
})

# %%
output[0]['generated_text']
# Out:
# "The interviewer will interview me as a Machine Learning expert. I am a machine learning expert in the field of artificial intelligence. I have a background in computer science and is a graduate student in the University of California at Berkeley's Department of Machine Learning. I also have a master's degree in the subject."

# %%
output = query({
    "inputs": "She smailed as she saw",
})
output[0]['generated_text']
# Out:
# "The woman is upset because she saw something she didn't want to see. She smails as she sees the person she was looking at. She is not happy with the person they are looking at and is not sure what it is. The person she is looking at is crying."
